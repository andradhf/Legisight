# %% [markdown]
# <a href="https://colab.research.google.com/github/andradhf/Legisight/blob/petitum/EDA_dataPutusanMk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
putusan_df = pd.read_csv('/content/splp_perkara_202504150803.csv')
putusan_df
# Out:
#         id  putusancode         no_perkara  \
# 0        1         4581   46/PUU-XXII/2024
# 1        2         4582   45/PUU-XXII/2024
# 2        3         4583   39/PUU-XXII/2024
# 3        4         4584   35/PUU-XXII/2024
# 4        5         4585   34/PUU-XXII/2024
# ...    ...          ...                ...
# 3690  3691         4645  104/PUU-XXII/2024
# 3691  3692         4646   95/PUU-XXII/2024
# 3692  3693         4647   80/PUU-XXII/2024
# 3693  3694         4648   63/PUU-XXII/2024
# 3694  3695         4649   140/PUU-XXI/2023
#
#                                           pokok_perkara  \
# 0     Pengujian Materiil Undang-Undang Nomor 10 Tahu...
# 1     Pengujian Materiil Undang-Undang Nomor 7 Tahun...
# 2     Pengujian Materiil Undang-Undang Nomor 19 Tahu...
# 3     Pengujian Materiil Undang-Undang Nomor 13 Tahu...
# 4     Pengujian Materiil Kitab Undang- Undang Hukum ...
# ...                                                 ...
# ...

# %%
status_counts = putusan_df['status'].value_counts()

plt.figure(figsize=(10, 6))
sns.countplot(x='status', data=putusan_df, order=status_counts.index)
plt.title('Status Distribution in Putusan Data')
plt.xlabel('Status')
plt.ylabel('Count')

# Add text annotations for each bar
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                    textcoords='offset points')


plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
putusan_df['status'].unique()
# Out:
# array(['Menolak Sebagian (Tidak Dapat Diterima)', 'Menolak Seluruhnya',
#        'Tidak Dapat Diterima', 'Mengabulkan Sebagian (Ditolak)', 'Gugur',
#        'Ditarik Kembali', 'Sela / Provisi', 'Mengabulkan Seluruhnya',
#        'Mengabulkan Sebagian',
#        'Mengabulkan Sebagian (Tidak Dapat Diterima)', '-',
#        'Tidak Berwenang',
#        'Mengabulkan Sebagian (Ditolak dan Tidak Dapat Diterima)',
#        'Mengabulkan Sebagian (Ditolak, Tidak Dapat Diterima, Tidak Berwenang dan Gugur)',
#        'Ditolak', 'Menolak Sebagian (Tidak Dapat Diterima dan Gugur)',
#        'Dikabulkan Sebagian', 'Sela',
#        'Menolak Sebagian (Tidak Dapat Diterima dan Tidak Berwenang)',
#        'Mengabulkan Sebagian (Ditolak, Tidak Dapat Diterima dan Tidak Berwenang)'],
#       dtype=object)

# %%
sela_df = putusan_df[putusan_df['status'] == 'Sela']

# Display the filtered DataFrame
sela_df
#mengambil klasifikasi dari amar putusan
# Out:
#         id  putusancode           no_perkara  \
# 1457  1458         2882  61/PHP.BUP-XVI/2018
# 1464  1465         2888  36/PHP.GUB-XVI/2018
# 1469  1470         2883  38/PHP.BUP-XVI/2018
#
#                                           pokok_perkara  \
# 1457  Perselisihan Hasil Pemilihan Bupati Timor Teng...
# 1464  Perselisihan Hasil Pemilihan Gubernur MALUKU U...
# 1469  Perselisihan Hasil Pemilihan Bupati Sampang Ta...
#
#                                                 pemohon  \
# 1457  <b>Drs. Obed Naitboho, M.Si.</b> dan <b>Alexan...
# 1464  <b>K.H. Abdul Gani Kasuba, Lc.</b> dan <b>Ir. ...
# 1469  <b>Drh. H. Hermanto Subaidi, M.Si.</b> dan <b>...
#
#                                            amar_putusan  download_count  \
# 1457  1.Memerintahkan kepada Komisi Pemilihan Umum K...          230665
# 1464  1.Menyatakan telah terjadi ketidakakuratan dal...          230670
# 1469  1. Menyatakan telah terjadi pemungutan suara p...          230502
#
# ...

# %%
supporting_file = sela_df['supporting_file'].iloc[0]
supporting_file
# Out:
# 'https://s.mkri.id/public/content/persidangan/putusan/5258_2405_putusan.pdf'

# %%
gugur_df = putusan_df[putusan_df['status'] == 'Gugur']
gugur_df
#unclasified document
# Out:
#         id  putusancode                            no_perkara  \
# 7        8         4588                      57/PUU-XXII/2024
# 8        9         4589                      53/PUU-XXII/2024
# 9       10         4590                      51/PUU-XXII/2024
# 138    139         4441  206-02-05-11/PHPU.DPR-DPRD-XXII/2024
# 139    140         4442  255-02-04-11/PHPU.DPR-DPRD-XXII/2024
# ...    ...          ...                                   ...
# 3589  3590         4755               240/PHPU.BUP-XXIII/2025
# 3590  3591         4756               205/PHPU.GUB-XXIII/2025
# 3591  3592         4758               66/PHPU.WAKO-XXIII/2025
# 3592  3593         4751               142/PHPU.BUP-XXIII/2025
# 3675  3676         4661                     141/PUU-XXII/2024
#
#                                           pokok_perkara  \
# 7     Pengujian Materiil Undang Undang Nomor 7 Tahun...
# 8     Pengujian Undang-Undang Nomor 1 Tahun 1970 ten...
# ...

# %%
gugur_file = gugur_df['supporting_file'].iloc[0]
gugur_file
# Out:
# 'https://s.mkri.id/public/content/persidangan/putusan/putusan_mkri_10880_1722311147.pdf'

# %%
menolak_df = putusan_df[putusan_df['status'] == 'Menolak Seluruhnya']
menolak_df
#klasifikasi dari petitum
# Out:
#         id  putusancode         no_perkara  \
# 1        2         4582   45/PUU-XXII/2024
# 3        4         4584   35/PUU-XXII/2024
# 5        6         4586   162/PUU-XXI/2023
# 13      14         4573   36/PUU-XXII/2024
# 14      15         4574   33/PUU-XXII/2024
# ...    ...          ...                ...
# 3687  3688         4642  109/PUU-XXII/2024
# 3688  3689         4643  108/PUU-XXII/2024
# 3691  3692         4646   95/PUU-XXII/2024
# 3692  3693         4647   80/PUU-XXII/2024
# 3694  3695         4649   140/PUU-XXI/2023
#
#                                           pokok_perkara  \
# 1     Pengujian Materiil Undang-Undang Nomor 7 Tahun...
# 3     Pengujian Materiil Undang-Undang Nomor 13 Tahu...
# 5     Pengujian Materiil Undang-Undang Nomor 20 Tahu...
# 13    Pengujian Materiil  Kitab Undang-Undang Hukum ...
# 14    Pengujian Materiil Undang-Undang Nomor 14 Tahu...
# ...                                                 ...
# ...

# %%
menolak_file = menolak_df['supporting_file'].iloc[0]
menolak_file
# Out:
# 'https://s.mkri.id/public/content/persidangan/putusan/putusan_mkri_10886_1722318724.pdf'

# %%
mengabulkan_df = putusan_df[putusan_df['status'] == 'Mengabulkan Seluruhnya']
mengabulkan_df
#amar putusan
# Out:
#         id  putusancode                            no_perkara  \
# 21      22         4567              03-03/PHPU.DPD-XXII/2024
# 70      71         4514   20-01-04-01/PHPU.DPR-DPRD-XXII/2024
# 79      80         4503  284-01-02-20/PHPU.DPR-DPRD-XXII/2024
# 90      91         4479   05-01-12-38/PHPU.DPR-DPRD-XXII/2024
# 99     100         4469  225-01-01-04/PHPU.DPR-DPRD-XXII/2024
# ...    ...          ...                                   ...
# 3406  3407           97                    014/PHPU.A-II/2004
# 3419  3420           22                        017/PUU-I/2003
# 3421  3422           21                        011/PUU-I/2003
# 3649  3650         4686                      62/PUU-XXII/2024
# 3660  3661         4669                     136/PUU-XXII/2024
#
#                                           pokok_perkara  \
# 21    Perselisihan Hasil Pemilihan Umum Anggota DPD ...
# 70    Perselisihan Hasil Pemilihan Umum Anggota DPR ...
# ...

# %%
mengabulkan_file = mengabulkan_df['supporting_file'].iloc[0]
mengabulkan_file
# Out:
# 'https://s.mkri.id/public/content/persidangan/putusan/putusan_mkri_10763_1718021592.pdf'

# %%
sebagian_df = putusan_df[putusan_df['status'] == 'Mengabulkan Sebagian']
sebagian_df
#amarputusan
# Out:
#         id  putusancode                            no_perkara  \
# 25      26         4570  269-01-08-15/PHPU.DPR-DPRD-XXII/2024
# 26      27         4564  261-01-12-15/PHPU.DPR-DPRD-XXII/2024
# 27      28         4572  118-01-14-15/PHPU.DPR-DPRD-XXII/2024
# 28      29         4551  221-01-12-37/PHPU.DPR-DPRD-XXII/2024
# 32      33         4554   09-01-14-11/PHPU.DPR-DPRD-XXII/2024
# 34      35         4556  219-01-14-23/PHPU.DPR-DPRD-XXII/2024
# 39      40         4548  158-02-16-37/PHPU.DPR-DPRD-XXII/2024
# 40      41         4549  185-02-16-37/PHPU.DPR-DPRD-XXII/2024
# 41      42         4550  177-02-16-37/PHPU.DPR-DPRD-XXII/2024
# 42      43         4536   98-01-05-26/PHPU.DPR-DPRD-XXII/2024
# 45      46         4539  202-01-08-33/PHPU.DPR-DPRD-XXII/2024
# 62      63         4506   21-02-08-18/PHPU.DPR-DPRD-XXII/2024
# 65      66         4509  184-01-04-02/PHPU.DPR-DPRD-XXII/2024
# 67      68         4511   16-01-22-01/PHPU.DPR-DPRD-XXII/2024
# ...

# %%
sebagian_file = sebagian_df['supporting_file'].iloc[0]
sebagian_file
# Out:
# 'https://s.mkri.id/public/content/persidangan/putusan/putusan_mkri_10761_1718022736.pdf'

# %%
tb_df = putusan_df[putusan_df['status'] == 'Tidak Berwenang']
tb_df
#return tidak berwenang
# Out:
#         id  putusancode                            no_perkara  \
# 178    179         4408  204-02-10-09/PHPU.DPR-DPRD-XXII/2024
# 185    186         4389  210-02-14-18/PHPU.DPR-DPRD-XXII/2024
# 186    187         4390  195-02-08-18/PHPU.DPR-DPRD-XXII/2024
# 204    205         4364  165-01-05-20/PHPU.DPR-DPRD-XXII/2024
# 218    219         4378  283-01-03-06/PHPU.DPR-DPRD-XXII/2024
# 254    255         4313   23-02-04-01/PHPU.DPR-DPRD-XXII/2024
# 255    256         4314  233-02-23-01/PHPU.DPR-DPRD-XXII/2024
# 256    257         4315   25-02-08-01/PHPU.DPR-DPRD-XXII/2024
# 273    274         4301  194-02-16-33/PHPU.DPR-DPRD-XXII/2024
# 316    317         4273  160-02-08-12/PHPU.DPR-DPRD-XXII/2024
# 317    318         4274  157-02-02-12/PHPU.DPR-DPRD-XXII/2024
# 328    329         4240   142-02-0-12/PHPU.DPR-DPRD-XXII/2024
# 646    647         3821                   154/PHP.BUP-XX/2022
# 660    661         3801                  153/PHP.BUP-XIX/2021
# ...

# %%
tb_file = tb_df['supporting_file'].iloc[0]
tb_file
# Out:
# 'https://s.mkri.id/public/content/persidangan/putusan/putusan_mkri_10348_1716348968.pdf'
